# %% [markdown]
# <a href="https://colab.research.google.com/github/UsamaMed/data_science/blob/main/API_JSON_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import time

# %%
# a GET request to the API
response = requests.get('https://api.coindesk.com/v1/bpi/currentprice.json')

#  if the request  successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    df = response.json()

    # Extract the Bitcoin price
    bitcoin_price = data['bpi']['USD']['rate']

    print(f"The current Bitcoin price is {bitcoin_price}")
else:
    print(f"Error: Unable to fetch data from the API. Status code: {response.status_code}")
# Out:
# The current Bitcoin price is 34,597.6441

# %%
df
# Out:
# {'time': {'updated': 'Oct 31, 2023 21:28:00 UTC',
#   'updatedISO': '2023-10-31T21:28:00+00:00',
#   'updateduk': 'Oct 31, 2023 at 21:28 GMT'},
#  'disclaimer': 'This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org',
#  'chartName': 'Bitcoin',
#  'bpi': {'USD': {'code': 'USD',
#    'symbol': '&#36;',
#    'rate': '34,627.8058',
#    'description': 'United States Dollar',
#    'rate_float': 34627.8058},
#   'GBP': {'code': 'GBP',
#    'symbol': '&pound;',
#    'rate': '28,934.7175',
#    'description': 'British Pound Sterling',
#    'rate_float': 28934.7175},
#   'EUR': {'code': 'EUR',
#    'symbol': '&euro;',
#    'rate': '33,732.5385',
#    'description': 'Euro',
#    'rate_float': 33732.5385}}}

# %%
df = {
    'time': {
        'updated': 'Oct 31, 2023 21:28:00 UTC',
        'updatedISO': '2023-10-31T21:28:00+00:00',
        'updateduk': 'Oct 31, 2023 at 21:28 GMT'
    },
    'disclaimer': 'This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org',
    'chartName': 'Bitcoin',
    'bpi': {
        'USD': {
            'code': 'USD',
            'symbol': '&#36;',
            'rate': '34,627.8058',
            'description': 'United States Dollar',
            'rate_float': 34627.8058
        },
        'GBP': {
            'code': 'GBP',
            'symbol': '&pound;',
            'rate': '28,934.7175',
            'description': 'British Pound Sterling',
            'rate_float': 28934.7175
        },
        'EUR': {
            'code': 'EUR',
            'symbol': '&euro;',
            'rate': '33,732.5385',
            'description': 'Euro',
            'rate_float': 33732.5385
        }
    }
}

# Convert the JSON data to a DataFrame
df = pd.DataFrame(df)

# %%
df
# Out:
#                                  time  \
# updated     Oct 31, 2023 21:28:00 UTC
# updatedISO  2023-10-31T21:28:00+00:00
# updateduk   Oct 31, 2023 at 21:28 GMT
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %%
df.isnull().sum()
# Out:
# time          3
# disclaimer    0
# chartName     0
# bpi           3
# dtype: int64
